# %%
import keras
model = keras.models.load_model("best-model.keras")

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image 

image = np.array(Image.open("sample.jpg").resize((224, 224)))

# %%
image = np.invert(image)
image.shape
# Out:
# (224, 224, 3)

# %%
predictions = model.predict(image[np.newaxis, :, :, :])
index = int(np.argmax(predictions, axis=1))
categories[index]

answers = np.argsort(predictions[0]).tolist()
answers.reverse()
categories[answers[:3]]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# C:\Users\admin\AppData\Local\Temp\ipykernel_139024\3173922637.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   index = int(np.argmax(predictions, axis=1))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 predictions = model.predict(image[np.newaxis, :, :, :])
#       2 index = int(np.argmax(predictions, axis=1))
# ----> 3 categories[index]
#       5 answers = np.argsort(predictions[0]).tolist()
#       6 answers.reverse()
#
# NameError: name 'categories' is not defined
