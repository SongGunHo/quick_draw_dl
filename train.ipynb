# %%
import numpy as np

from PIL import Image
from sklearn.model_selection import train_test_split

# %%
for i in range(49):
    data_path = f"data/data{i}.npy"
    target_path = f"data/target{i}.npy"
    train_data = np.load(data_path)
    target_data = np.load(target_path)
    total = train_data.shape[0]
    items = np.zeros((total, 224, 224, 3), dtype=np.uint8)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 data_path = f"data/data{i}.npy"
#       3 target_path = f"data/target{i}.npy"
# ----> 4 train_data = np.load(data_path)
#       5 target_data = np.load(target_path)
#       6 total = train_data.shape[0]
#
# File c:\project\Quick_Draw\.venv\Lib\site-packages\numpy\lib\_npyio_impl.py:459, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     457     own_fid = False
#     458 else:
# --> 459     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     460     own_fid = True
#     462 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/data0.npy'
