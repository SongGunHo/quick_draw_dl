# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\project\quick_draw\.venv\lib\site-packages (1.7.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\project\quick_draw\.venv\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\project\quick_draw\.venv\lib\site-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\project\quick_draw\.venv\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\project\quick_draw\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 훈련세트 검증세트 , 테스트 세트 
import numpy as np 
from glob import glob
from sklearn.model_selection import train_test_split
from PIL import Image

# %%
# 이미지 데이터 하나로 불러오기 
files = [(path, path.replace("data_original\\", "").replace(".npy", "")) for path in glob("data_original/*")]
# 분류 정보 처리
categories = [category for _, category in files]

np.save('category.npy', np.array(categories))

# %%
items = np.zeros((len(files) * 12000, 28, 28), dtype=np.uint8)
target = np.zerors((len(files), ), dtype=np.uint8)
for i, item in enumerate(files):
    path, category = item
    target = categories.index(category)
    print
    data = np.load(path)
    for j in range(12000):
        rows = i * 12000 + j
        items[rows] = data[j].reshape(-1, 28, 28)

items.shape
# Out:
#   Cell In[34], line 2
#     target = np.zerors((len(files), dtype=np.uint8))
#                                     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#files = [(path, path.replace("data\\", "").replace(".npy", "")) for path in glob("data/*")]
#total = len(files) * 10000
#train_data = np.zeros((total, 224, 224), dtype=np.uint8)
#target_data = np.zeros((total,), dtype=np.uint8)

#print(train_data.shape, target_data.shape)
# Out:
# (90000, 224, 224) (90000,)

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\project\quick_draw\.venv\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\project\quick_draw\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\project\quick_draw\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\project\quick_draw\.venv\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\project\quick_draw\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\project\quick_draw\.venv\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\project\quick_draw\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\project\quick_draw\.venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\project\quick_draw\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\project\quick_draw\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\project\quick_draw\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
plt.imshow(items[0], cmap='gray_r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.random.shuffle(items)

# %%
indexes =- np.arange(items.shape[0])
np.ramdom.shuffle(indexes)

items = itesm[indexes, :, : ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 indexes =- np.arange(items.shape[0])
# ----> 2 np.ramdom.shuffle(indexes)
#       3 indexex[:10]
#
# File c:\project\Quick_Draw\.venv\Lib\site-packages\numpy\__init__.py:427, in __getattr__(attr)
#     424     import numpy.char as char
#     425     return char.chararray
# --> 427 raise AttributeError("module {!r} has no attribute "
#     428                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'ramdom'

# %%
plt.imshow(items[0], cmap='gray_r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
rows = int(np.cail(items.shape[0]/ 12000))
for i in range(49):
    start = i *12000
    data = items[start: start +12000:12000, :, :]
    target = target[start: start + 12000]
    np.save(f"data/data{i}.npy", data)
    np.save(f"data/target{i}.npy", data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 rows = int(np.cail(items.shape[0]/ 12000))
#       2 for i in range(49):
#       3     start = i *12000
#
# File c:\project\Quick_Draw\.venv\Lib\site-packages\numpy\__init__.py:427, in __getattr__(attr)
#     424     import numpy.char as char
#     425     return char.chararray
# --> 427 raise AttributeError("module {!r} has no attribute "
#     428                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'cail'
